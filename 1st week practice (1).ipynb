# %%
import sys 
sys.version
# Out:
# '3.13.5 | packaged by Anaconda, Inc. | (main, Jun 12 2025, 16:37:03) [MSC v.1929 64 bit (AMD64)]'

# %% [markdown]
# # pyton variable =identifier=object
# syntax(variable=value)

# %%
v=8
v
# Out:
# 8

# %% [markdown]
# # rules to declare python variable

# %%
var=8 # variable case sensitive 
V
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 var=8 # variable case sensitive
# ----> 2 V
#
# NameError: name 'V' is not defined

# %%
var="hello"
VAr
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[78], line 2
#       1 var="hello"
# ----> 2 VAr
#
# NameError: name 'VAr' is not defined

# %%
var1="hello"
var1
# Out:
# 'hello'

# %%
var
# Out:
# 8

# %%
VAR2="manimegha"
var2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[80], line 2
#       1 VAR2="manimegha"
# ----> 2 var2
#
# NameError: name 'var2' is not defined

# %%
VAR3="KEERTHI"
VAR3
# Out:
# 'KEERTHI'

# %%
m@=9# special characters are not allowed WHILE DECLARING A VARIABLE
m
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 m@=9# special characters are not allowed
#       2 m
#
# NameError: name 'm' is not defined

# %%
v@1="python"
v@1
# Out:
#   Cell In[82], line 1
#     v@1="python"
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
a$2="hello"
a$2
# Out:
#   Cell In[83], line 1
#     a$2="hello"
#      ^
# SyntaxError: invalid syntax

# %%
a&b&c="world"
a&b&c
# Out:
#   Cell In[84], line 1
#     a&b&c="world"
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
a.="vardhan"
a.
# Out:
#   Cell In[85], line 1
#     a.="vardhan"
#       ^
# SyntaxError: invalid syntax

# %%
# we use underscore while declaring a variable

# %%
variable_name="mango"
variable_name
# Out:
# 'mango'

# %%
v_=30 # _ is allowed
v_
# Out:
# 30

# %%
var_123=900
var_123
# Out:
# 900

# %%
# we should not start with numbeers but end with numbers while decalaring  a variable

# %%
1var=25# digits are not allowed at first of variable
1var
# Out:
#   Cell In[7], line 1
#     1var=25# digits are not allowed at first of variable
#     ^
# SyntaxError: invalid decimal literal

# %%
123var="mani"
123var
# Out:
#   Cell In[88], line 1
#     123var="mani"
#       ^
# SyntaxError: invalid decimal literal

# %%
10var="python"
10var
# Out:
#   Cell In[89], line 1
#     10var="python"
#      ^
# SyntaxError: invalid decimal literal

# %%
0var="shivani"
0var
# Out:
#   Cell In[90], line 1
#     0var="shivani"
#     ^
# SyntaxError: invalid decimal literal

# %%
var21="mani"
var21
# Out:
# 'mani'

# %%
var22=400
var22
# Out:
# 400

# %%
var23iable=100
var23iable
# Out:
# 100

# %%
v1r=6000
v1r
# Out:
# 6000

# %%
var1=45# digits are allowed at last 
var1
# Out:
# 45

# %%
1var=19
# Out:
#   Cell In[9], line 1
#     1var=19
#     ^
# SyntaxError: invalid decimal literal

# %%
# we should not use keyword names as a variable name

# %%
False=0
False
# Out:
#   Cell In[95], line 1
#     False=0
#     ^
# SyntaxError: cannot assign to False

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
false=0
false
# Out:
# 0

# %%
True=1
True
# Out:
#   Cell In[97], line 1
#     True=1
#     ^
# SyntaxError: cannot assign to True

# %%
len(keyword.kwlist)
# Out:
# 35

# %%
true=1
true
# Out:
# 1

# %%
none="None"
none
# Out:
# 'None'

# %%
None="None"
None
# Out:
#   Cell In[100], line 1
#     None="None"
#     ^
# SyntaxError: cannot assign to None

# %%
while="it is a loop"
while
# Out:
#   Cell In[101], line 1
#     while="it is a loop"
#          ^
# SyntaxError: invalid syntax

# %%
if="condition"
if
# Out:
#   Cell In[102], line 1
#     if="condition"
#       ^
# SyntaxError: invalid syntax

# %%
for=9
# Out:
#   Cell In[12], line 1
#     for=9
#        ^
# SyntaxError: invalid syntax

# %%
and="python"
and
# Out:
#   Cell In[103], line 1
#     and="python"
#     ^
# SyntaxError: invalid syntax

# %%
return="python"
return
# Out:
#   Cell In[104], line 1
#     return="python"
#           ^
# SyntaxError: invalid syntax

# %%
continue=300
continue
# Out:
#   Cell In[105], line 1
#     continue=300
#             ^
# SyntaxError: invalid syntax

# %%
# we should not give space instead  of space we use underscore

# %%
variable name="mani"
variable name
# Out:
#   Cell In[106], line 1
#     variable name="mani"
#              ^
# SyntaxError: invalid syntax

# %%
variable_name="nani"
variable_name
# Out:
# 'nani'

# %%
def=19
def
# Out:
#   Cell In[13], line 1
#     def=19
#        ^
# SyntaxError: invalid syntax

# %%
DEF=34
DEF
# Out:
# 34

# %% [markdown]
# # integer variable

# %%
age=26
print(age)
# Out:
# 26

# %% [markdown]
# # string variable

# %%
name="manimegha"
print(name)
# Out:
# manimegha

# %% [markdown]
# #float variable

# %%
price=19.0
print(price)
# Out:
# 19.0

# %%
is_active=True
print(is_active)
# Out:
# True

# %%
m=True
print(m)
# Out:
# True

# %% [markdown]
# # storing and printing a value

# %%
x=11
x
# Out:
# 11

# %% [markdown]
# # using variables in expressions

# %%
a=4
b=9
result=a+b
print(result)
# Out:
# 13

# %% [markdown]
# # changing the value of a variable

# %%
score=90
print(score)
# Out:
# 90

# %%
score=100
print(score)
# Out:
# 100

# %% [markdown]
# #concatenating strings

# %%
first_name="manimegha"
last_name="gajjela"
full_name=first_name+last_name
print(full_name)
# Out:
# manimeghagajjela

# %%
first_name="manimegha"
last_name="gajjela"
full_name=first_name+" "+last_name
print(full_name)
# Out:
# manimegha gajjela

# %% [markdown]
#  # using variable in a calculation

# %%
length=30
width=40
area=length*width
print(area)
# Out:
# 1200

# %% [markdown]
# #python variable declaration

# %%
false=78# false and true are keywords
false
# Out:
# 78

# %%
False=40
False
# Out:
#   Cell In[28], line 1
#     False=40
#     ^
# SyntaxError: cannot assign to False

# %%
True=80
True
# Out:
#   Cell In[29], line 1
#     True=80
#     ^
# SyntaxError: cannot assign to True

# %%
true=47
true
# Out:
# 47

# %% [markdown]
# #python data types
# int
# float
# bool
# string
# complex

# %% [markdown]
# # int

# %%
int=70
int
# Out:
# 70

# %%
i=96
i
# Out:
# 96

# %%
type(i)
# Out:
# int

# %%
num=1000
num
# Out:
# 1000

# %%
type(num)
# Out:
# int

# %% [markdown]
# # float

# %%
f=13.6
f
# Out:
# 13.6

# %%
type(f)
# Out:
# float

# %%
i
# Out:
# 96

# %%
f
# Out:
# 13.6

# %%
i
f
# Out:
# 13.6

# %%
print(i)
print(f)
# Out:
# 96
# 13.6

# %%
i+f
# Out:
# 109.6

# %%
i-f
# Out:
# 82.4

# %%
i*f
# Out:
# 1305.6

# %%
num1=23.57
num1
# Out:
# 23.57

# %%
a=10
b-40.5
c=a+b
c
# Out:
# 19

# %%
type(c)
# Out:
# int

# %%
type(num1)
# Out:
# float

# %%
num3=1e0
num3
# Out:
# 1.0

# %%
type(num3)
# Out:
# float

# %%
num4=2e0
num4
# Out:
# 2.0

# %%
type(num4)
# Out:
# float

# %%
num5=2e10
num5
# Out:
# 20000000000.0

# %% [markdown]
# # bool

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
True+True
# Out:
# 2

# %%
False+True
# Out:
# 1

# %%
True+False
# Out:
# 1

# %%
False+False
# Out:
# 0

# %%
False*True
# Out:
# 0

# %%
True/False
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[121], line 1
# ----> 1 True/False
#
# ZeroDivisionError: division by zero

# %%
False/True
# Out:
# 0.0

# %%
False//True
# Out:
# 0

# %%
True%False
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[124], line 1
# ----> 1 True%False
#
# ZeroDivisionError: integer modulo by zero

# %%
True/True
# Out:
# 1.0

# %%
False%True
# Out:
# 0

# %%
True//True
# Out:
# 1

# %% [markdown]
# # string

# %%
s=manimegha
s
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 s=manimegha
#       2 s
#
# NameError: name 'manimegha' is not defined

# %%
s='shivani'
s
# Out:
# 'shivani'

# %%
s1="hello"
s1
# Out:
# 'hello'

# %%
s2='''hello'''
s2
# Out:
# 'hello'

# %%
s3='''hello
           team'''
s3
# Out:
# 'hello\n           team'

# %%
str=hello
str
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[126], line 1
# ----> 1 str=hello
#       2 str
#
# NameError: name 'hello' is not defined

# %%
str1='hello'
str1
# Out:
# 'hello'

# %%
str2="hello python"
str2
# Out:
# 'hello python'

# %% [markdown]
# # complex

# %%
c=20+40j
c
# Out:
# (20+40j)

# %%
c.real
# Out:
# 20.0

# %%
c.imag
# Out:
# 40.0

# %%
c=50+60j
d=60+40j
print(c+d)
# Out:
# (110+100j)

# %%
print(c-d)
print(c*d)
print(c/d)
# Out:
# (-10+20j)
# (600+5600j)
# (1.0384615384615385+0.30769230769230776j)

# %%
c2=1+2J # it will take j capital also
c2
# Out:
# (1+2j)

# %%
a=1+2j
a
# Out:
# (1+2j)

# %%
type(a)
# Out:
# complex

# %%
a.real
# Out:
# 1.0

# %%
a.imag
# Out:
# 2.0

# %%
b=10+20j
c=20+30j
d=b+c
d
# Out:
# (30+50j)

# %%
type(d)
# Out:
# complex

# %%
e=b-c
e
# Out:
# (-10-10j)

# %%
type(e)
# Out:
# complex

# %%
e1=c-b
e1
# Out:
# (10+10j)

# %%
f=b*c
f
# Out:
# (-400+700j)

# %%
type(e1)
# Out:
# complex

# %% [markdown]
# # Type casting== convert one data type to other data type

# %% [markdown]
# # other data types to integer

# %%
int(2.4)
# Out:
# 2

# %%
int(2.4,3.5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 int(2.4,3.5)
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
int(false)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 int(false)
#
# NameError: name 'false' is not defined

# %%
int(True,False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 int(True,False)
#
# TypeError: int() can't convert non-string with explicit base

# %%
int('19')
# Out:
# 19

# %%
int('ten')# text string  cant convert  int
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 int('ten')
#
# ValueError: invalid literal for int() with base 10: 'ten'

# %%
int(1+2j)# complex cant convert to int
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 int(1+2j)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
#float to integer
int(2.45)
# Out:
# 2

# %%
#boolean to integer
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
int(0)
# Out:
# 0

# %%
int(1)
# Out:
# 1

# %%
#text string to integer(not possible)
int("anjali")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 2
#       1 #text string to integer(not possible)
# ----> 2 int("anjali")
#
# ValueError: invalid literal for int() with base 10: 'anjali'

# %%
#number string to integer
int("10")
# Out:
# 10

# %%
#complex to integer 
int(10+20j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 2
#       1 #complex to integer
# ----> 2 int(10+20j)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
int(10+20)
# Out:
# 30

# %% [markdown]
# #  all other data types to float

# %%
float(300)
# Out:
# 300.0

# %%
float(10,20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 float(10,20)
#
# TypeError: float expected at most 1 argument, got 2

# %%
float(1+3j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 float(1+3j)
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %%
float(True)
# Out:
# 1.0

# %%
float(False)
# Out:
# 0.0

# %%
float(20)
# Out:
# 20.0

# %%
float('ten')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 float('ten')
#
# ValueError: could not convert string to float: 'ten'

# %%
#integer to float
float(10)
# Out:
# 10.0

# %%
float(200.00)
# Out:
# 200.0

# %%
float(20.435)
# Out:
# 20.435

# %%
#boolean to float
float(True)
# Out:
# 1.0

# %%
float(False)
# Out:
# 0.0

# %%
 text string to float(not possible)
float("anjali")
# Out:
#   Cell In[38], line 1
#     text string to float(not possible)
#          ^
# SyntaxError: invalid syntax

# %%
#number string to float
float("10")
# Out:
# 10.0

# %%
#complex to float(not possible)
float(10+20j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 2
#       1 #complex to float(not possible)
# ----> 2 float(10+20j)
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %%
float(10+20)
# Out:
# 30.0

# %%
float(10+20+30+40)
# Out:
# 100.0
